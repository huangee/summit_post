# %%
import nltk
import pandas as pd
import numpy as np
import re
import string

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import TruncatedSVD, NMF
from sklearn.metrics.pairwise import cosine_similarity

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('climber_logs.csv')
data['comment_date'] = pd.to_datetime(data['comment_date'])
data['climb_date'] = pd.to_datetime(data['climb_date'])
data['comment'] = data['comment'].replace(np.nan, '', regex=True)

print(data.info())
data.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35638 entries, 0 to 35637
# Data columns (total 4 columns):
# mountain        35638 non-null object
# comment         35638 non-null object
# comment_date    35638 non-null datetime64[ns]
# climb_date      22860 non-null datetime64[ns]
# dtypes: datetime64[ns](2), object(2)
# memory usage: 1.1+ MB
# None
#         mountain                                            comment  \
# 0  Mount Whitney  Did this in a single day... very difficult for...
# 1  Mount Whitney                    Mountaineers Route - first 14er
# 2  Mount Whitney  Standard route from Whitney Portal via Trail C...
# 3  Mount Whitney  Worth hiking the 220-something miles along the...
# 4  Mount Whitney  My brother John, his son and I backpacked in t...
# 5  Mount Whitney  Words will never describe the breathtaking vie...
# 6  Mount Whitney                                Portal out and back
# 7  Mount Whitney  Great 2am ascent from Trail Camp.\nhttps://the...
# 8  Mount Whitney  Hiked from guitar lake in the middle of the ni...
# 9  Mount Whitney  Summited Whitney via the Whitney Trail with tw...
#
#          comment_date climb_date
# 0 2018-11-19 08:51:00 2015-09-05
# 1 2018-11-01 06:34:00        NaT
# 2 2018-10-01 12:44:00 2018-10-27
# 3 2018-09-10 10:23:00 2016-07-23
# 4 2018-08-15 02:28:00 2018-08-10
# 5 2018-08-02 11:50:00 2018-07-01
# 6 2018-07-31 07:51:00 2018-07-29
# 7 2018-07-28 20:09:00 2018-07-28
# 8 2018-07-24 06:33:00 2014-08-08
# 9 2018-07-02 07:31:00 2018-06-24

# %%
# preprocess text - change to lowercase, remove numbers and punctuation

alphanumeric = lambda x: re.sub('\w*\d\w*', ' ', x)
no_new_line = lambda x: re.sub('\n', '', x)
punc_lower = lambda x: re.sub('[%s]' % re.escape(string.punctuation), ' ', x.lower())

data['comment'] = data.comment.map(alphanumeric).map(punc_lower).map(no_new_line)
data.head()
# Out:
#         mountain                                            comment  \
# 0  Mount Whitney  did this in a single day    very difficult for...
# 1  Mount Whitney                       mountaineers route   first
# 2  Mount Whitney  standard route from whitney portal via trail c...
# 3  Mount Whitney  worth hiking the   something miles along the j...
# 4  Mount Whitney  my brother john  his son and i backpacked in t...
#
#          comment_date climb_date
# 0 2018-11-19 08:51:00 2015-09-05
# 1 2018-11-01 06:34:00        NaT
# 2 2018-10-01 12:44:00 2018-10-27
# 3 2018-09-10 10:23:00 2016-07-23
# 4 2018-08-15 02:28:00 2018-08-10

# %%
sample = data['comment'].sample(1000)

# %% [markdown]
# ## Find Top Words with Count Vectorizer

# %%
cv1 = CountVectorizer(stop_words='english')
doc_word = cv1.fit_transform(sample).toarray()
doc_word.shape
# Out:
# (1000, 4875)

# %%
feature_names = cv1.get_feature_names()
sum_words = doc_word.sum(axis=0)

words_freq = [(word, sum_words[0, idx]) for word, idx in cv1.vocabulary_.items()]
words_freq = sorted(words_freq, key = lambda x: x[1], reverse=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-33-bc25b2b4a94e> in <module>
#       2 sum_words = doc_word.sum(axis=0)
#       3
# ----> 4 words_freq = [(word, sum_words[0, idx]) for word, idx in cv1.vocabulary_.items()]
#       5 words_freq = sorted(words_freq, key = lambda x: x[1], reverse=True)
#
# <ipython-input-33-bc25b2b4a94e> in <listcomp>(.0)
#       2 sum_words = doc_word.sum(axis=0)
#       3
# ----> 4 words_freq = [(word, sum_words[0, idx]) for word, idx in cv1.vocabulary_.items()]
#       5 words_freq = sorted(words_freq, key = lambda x: x[1], reverse=True)
#
# IndexError: too many indices for array

# %%
sum_words
# Out:
# array([1, 3, 4, ..., 1, 3, 1], dtype=int64)

# %%
words_freq[:20]
# Out:
# [(('little', 2443), 1),
#  (('long', 2463), 1),
#  (('easy', 1316), 1),
#  (('nice', 2824), 1),
#  (('views', 4533), 1),
#  (('awesome', 288), 1),
#  (('weekend', 4616), 1),
#  (('climb', 807), 1),
#  (('summit', 4097), 1),
#  (('daniel', 1064), 1),
#  (('night', 2835), 1),
#  (('camped', 626), 1),
#  (('moraine', 2724), 1),
#  (('glacier', 1741), 1),
#  (('big', 418), 1),
#  (('mistake', 2680), 1),
#  (('sun', 4106), 1),
#  (('went', 4627), 1),
#  (('winds', 4679), 1),
#  (('picked', 3095), 1)]

# %% [markdown]
# ## Find Top Words with TF-IDF Vectorizer

# %%
cv_tfidf = TfidfVectorizer(stop_words='english')
X_tfidf = cv_tfidf.fit_transform(sample).toarray()
X_tfidf.shape
# Out:
# (1000, 4787)

# %%
feature_array = np.array(cv_tfidf.get_feature_names())
tfidf_sorting = np.argsort(X_tfidf.flatten()[::-1])

n = 10
top_n = feature_array[tfidf_sorting][:n]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-f80f39b7e737> in <module>
#       4
#       5 n = 10
# ----> 6 top_n = feature_array[tfidf_sorting][:n]
#
# IndexError: index 3188068 is out of bounds for axis 1 with size 4787

# %% [markdown]
# ## testing LSA topic modeling

# %%
vectorizer = CountVectorizer(stop_words='english')
doc_word = vectorizer.fit_transform(sample)
doc_word.shape
# Out:
# (1000, 4787)

# %%
pd.DataFrame(doc_word.toarray(), index=sample, columns=vectorizer.get_feature_names()).head(10)
# Out:
#                                                     aasgard  ability  able  \
# comment
# a little long                                             0        0     0
# very easy  nice views up top                              0        0     0
# had an awesome weekend to climb to the e  summi...        0        0     0
# gorgeous day     lots of sp ers on the summit t...        0        0     0
# kelso ridge was very fun                                  0        0     0
# this is a long hike  make sure to leave enough ...        0        0     0
# very straight forward hike  trails are well mar...        0        0     0
# great climb                                               0        0     0
# took the west route and was surprised at how mu...        0        0     0
# not sure when i did it    sometime in   between...        0        0     0
#
#                                                     abol  abondoned  aborting  \
# comment
# a little long                                          0          0         0
# very easy  nice views up top                           0          0         0
# had an awesome weekend to climb to the e  summi...     0          0         0
# gorgeous day     lots of sp ers on the summit t...     0          0         0
# kelso ridge was very fun                               0          0         0
# this is a long hike  make sure to leave enough ...     0          0         0
# very straight forward hike  trails are well mar...     0          0         0
# great climb                                            0          0         0
# took the west route and was surprised at how mu...     0          0         0
# not sure when i did it    sometime in   between...     0          0         0
#
#                                                     abseil  absence  \
# comment
# a little long                                            0        0
# very easy  nice views up top                             0        0
# had an awesome weekend to climb to the e  summi...       0        0
# gorgeous day     lots of sp ers on the summit t...       0        0
# kelso ridge was very fun                                 0        0
# this is a long hike  make sure to leave enough ...       0        0
# very straight forward hike  trails are well mar...       0        0
# great climb                                              0        0
# took the west route and was surprised at how mu...       0        0
# not sure when i did it    sometime in   between...       0        0
#
#                                                     absolutely  abundant  ...  \
# comment                                                                   ...
# a little long                                                0         0  ...
# very easy  nice views up top                                 0         0  ...
# had an awesome weekend to climb to the e  summi...           0         0  ...
# gorgeous day     lots of sp ers on the summit t...           0         0  ...
# kelso ridge was very fun                                     0         0  ...
# this is a long hike  make sure to leave enough ...           0         0  ...
# very straight forward hike  trails are well mar...           0         0  ...
# great climb                                                  0         0  ...
# took the west route and was surprised at how mu...           0         0  ...
# not sure when i did it    sometime in   between...           0         0  ...
#
#                                                     zermatt  zero  zig  \
# comment
# a little long                                             0     0    0
# very easy  nice views up top                              0     0    0
# had an awesome weekend to climb to the e  summi...        0     0    0
# gorgeous day     lots of sp ers on the summit t...        0     0    0
# kelso ridge was very fun                                  0     0    0
# this is a long hike  make sure to leave enough ...        0     0    0
# very straight forward hike  trails are well mar...        0     0    0
# great climb                                               0     0    0
# took the west route and was surprised at how mu...        0     0    0
# not sure when i did it    sometime in   between...        0     0    0
#
#                                                     ziplock  zone  zoo  \
# comment
# a little long                                             0     0    0
# very easy  nice views up top                              0     0    0
# had an awesome weekend to climb to the e  summi...        0     0    0
# gorgeous day     lots of sp ers on the summit t...        0     0    0
# kelso ridge was very fun                                  0     0    0
# this is a long hike  make sure to leave enough ...        0     0    0
# very straight forward hike  trails are well mar...        0     0    0
# great climb                                               0     0    0
# took the west route and was surprised at how mu...        0     0    0
# not sure when i did it    sometime in   between...        0     0    0
#
#                                                     zoomed  zurbriggen  åsa  \
# comment
# a little long                                            0           0    0
# very easy  nice views up top                             0           0    0
# had an awesome weekend to climb to the e  summi...       0           0    0
# gorgeous day     lots of sp ers on the summit t...       0           0    0
# kelso ridge was very fun                                 0           0    0
# this is a long hike  make sure to leave enough ...       0           0    0
# very straight forward hike  trails are well mar...       0           0    0
# great climb                                              0           0    0
# took the west route and was surprised at how mu...       0           0    0
# not sure when i did it    sometime in   between...       0           0    0
#
#                                                     çlear
# comment
# a little long                                           0
# very easy  nice views up top                            0
# had an awesome weekend to climb to the e  summi...      0
# gorgeous day     lots of sp ers on the summit t...      0
# kelso ridge was very fun                                0
# this is a long hike  make sure to leave enough ...      0
# very straight forward hike  trails are well mar...      0
# great climb                                             0
# took the west route and was surprised at how mu...      0
# not sure when i did it    sometime in   between...      0
#
# [10 rows x 4787 columns]

# %%
lsa = TruncatedSVD(2) # getting N most important components/topics
doc_topic = lsa.fit_transform(doc_word)
lsa.explained_variance_ratio_
# Out:
# array([0.05362247, 0.02531442])

# %%
topic_word = pd.DataFrame(lsa.components_.round(3),
             index = ["component_1","component_2"],
             columns = vectorizer.get_feature_names())
topic_word
# Out:
#              aasgard  ability   able  abol  abondoned  aborting  abseil  \
# component_1    0.001    0.001  0.031   0.0      0.001       0.0   0.001
# component_2    0.002    0.000  0.052   0.0      0.000       0.0   0.000
#
#              absence  absolutely  abundant  ...  zermatt   zero    zig  \
# component_1    0.001       0.005       0.0  ...    0.013  0.001  0.001
# component_2   -0.001       0.000       0.0  ...    0.005 -0.002 -0.002
#
#              ziplock   zone    zoo  zoomed  zurbriggen  åsa  çlear
# component_1    0.001  0.001  0.001   0.001       0.001  0.0  0.001
# component_2    0.001 -0.002 -0.000  -0.001      -0.001  0.0  0.000
#
# [2 rows x 4787 columns]

# %%
def display_topics(model, feature_names, no_top_words, topic_names=None):
    for ix, topic in enumerate(model.components_):
        if not topic_names or not topic_names[ix]:
            print("\nTopic ", ix)
        else:
            print("\nTopic: '",topic_names[ix],"'")
        print(", ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))

# %%
display_topics(lsa, vectorizer.get_feature_names(), 5)
# Out:
# Topic  0
# summit, day, trail, time, route
#
# Topic  1
# time, route, base, exposure, reached

# %%
Vt = pd.DataFrame(doc_topic.round(5),
             index = sample,
             columns = ["component_1","component_2" ])
Vt
# Out:
#                                                     component_1  component_2
# comment
# a little long                                           0.11831     -0.02903
# very easy  nice views up top                            0.21568     -0.09829
# had an awesome weekend to climb to the e  summi...      1.40288     -0.44241
# gorgeous day     lots of sp ers on the summit t...      2.19534     -2.02799
# kelso ridge was very fun                                0.25307      0.12359
# this is a long hike  make sure to leave enough ...      0.45591      0.30053
# very straight forward hike  trails are well mar...      0.13776     -0.09279
# great climb                                             0.33241      0.14602
# took the west route and was surprised at how mu...      1.11784     -0.22949
# not sure when i did it    sometime in   between...      1.77290     -0.52779
# climbing half dome was the culmination of our  ...      3.55988     -0.46913
# route was in great shape and the weather was fa...      1.82273     -1.06302
# late august was perfect for climbing the cables...      2.59266      0.04873
# after    days camped on glacier in blizzard con...      0.57690     -0.47474
# traversed from jepson after climbing dollar cou...      1.76350     -0.54519
# from marco e rosa hut                                   0.05836     -0.06781
# more challenging than i expected but made the s...      1.22303     -0.77420
# an easy summit  but the snow at the willows on ...      3.55166     -0.67517
# southeast ridge  the climb out of black cloud g...      0.38994      0.25831
# nice hike with jobe wymore  from the highpoint ...      0.79123     -0.48643
# summit was very nice  arrived at the summit aro...      2.13105     -0.95569
# first day  azau to priut  diesel second day  su...      1.06464     -0.93846
# this was my first big summit on a snow covered ...      0.74361     -0.54456
# climbed again in april of     the summit had be...      0.80732     -0.40071
# after being in l a  for three months  sea level...      0.55989      0.10825
# climbed with the   others from summitpost   arr...      2.17338     -1.17168
# hiked up massive from the west slopes some time...      0.35336      0.32295
# this was my first climb of blanca  we hiked muc...      1.03321     -0.13462
# my second    and my first in the quest for them...      0.25568     -0.05241
# windy hike  the summit views worth it though  h...      0.65868     -0.62480
# ...                                                         ...          ...
# big slog from the west                                  0.07676     -0.01927
# when the bad weather moved in we quickly drove ...      0.69948      0.02095
# also did ellingwood  but the ridge to little be...      0.52073     -0.01158
# summited  nice day                                      0.47252     -0.35127
# in   our family did a highpoints driving trip a...      0.44183     -0.05985
# typical hike up from henry s fork trailhead  sc...      1.57846     -0.00047
# ran speed hiked the north loop route from trail...      1.61663      0.27878
# what a pyramid from the bottom  a must  left hu...      2.07626     -0.45319
# okay  not exactly  the dying conifers near the ...      0.44573     -0.46098
# beautiful crisp fall day for hiking  started up...      1.51061     -0.53742
# picked this up on my way to longs                       0.21126      0.08196
# absolutely perfect day  we left marble mt sno p...      1.87928     -0.63262
# great time and great views  albeit some ash in ...      0.61628      0.33309
# snow in several places  but hiking shoes and ga...      3.40333     -0.85344
# not too difficult a path  but rather long  took...      0.63229     -0.40568
# did the mr with conn doherty from iceberg lake          0.17206     -0.08839
# we did marcy on       from south meadows road  ...      1.14115      0.09195
# from trailhead over broken hand pass to summit ...      1.52106     -1.08905
# mosquitoes and near   degree temp  miserable   ...      0.02801     -0.02465
# waited out the wind for   days entertained by c...      0.54794      0.25313
# it s been a while  but i do remember being ther...      3.13222     -0.16458
# good weather for december  strong winds on the ...      0.61785     -0.50279
# less than   months later the route was super dr...      0.32144      0.15162
# my wife and i summit a different local peak for...      1.26230     -0.54972
# cold                                                    0.04601     -0.00943
# my first time to the top of this mountain was b...      1.37030      0.44046
#    with caltech alpine club on their annual adv...      0.17325      0.06401
#   of three this day   with pa and wv   it was n...      1.30087      0.16029
# windy spring day  started at noon was back to t...      0.52388     -0.44115
# took the oneidas road to fountain place and cli...      1.94748      0.80217
#
# [1000 rows x 2 columns]
